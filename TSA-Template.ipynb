# %% [markdown]
# - Pendahuluan Time Series:
#  * time series dan sequential model serta bedanya dengan metode yang bukan time-series.
#  * mengapa TSF penting
#  * Contoh beberapa masalah TSF di kehidupan nyata ==> juga akan dipakai dalam studi kasus
#  * Case Studies: Finance, Predictive maintenance, health, Politics, Environment
#  * beberapa istilah penting di TSA: Autocorrelation, Trend, seasonal, Moving Average, sliding windows, etc.
#  * Multivariate vs Multiple Time Series
#  * Pendahuluan ini bagus pakai bukunya Jason Brownlee
#
# - Pendahuluan Python: (Optional ... bisa dideliver oleh orang lain)
#  * Syntax, struktur data, & Logic Dasar
#  * module dasar: numpy, matplotlib, pandas, tqdm, dsb.
#  * Array & Dataframe: loc, iloc, indexing, operasi/manipulasi dasar.
#
# - EDA di Time Series:
#  * loading time information (dari satu kolom & beberapa kolom, date berupa string, dll)
#  - Latihan load dengan berbagai macam data yg tricky.
#  - Operasi pada kolom datetime, terutama tanggal + atau kurang suatu waktu.
#  - Sekedar informasikan saja kalau dgn Database lebih mudah.
#  * Data Manipulation: mean average, data aggregate: monthly, weekly, concat/merge, etc.
#  * Noise filtering ==> Filtering for noisy data: Kalman filter atau yg lain.
#  * Handling missing values pada data time series
#  * Autocorrelation (ACF dan PACF) dan statistika dasar lain di data Time series
#  * Scaling/Standardize data
#  * Past-Future Covariates
#
# - Visualisasi data time series: As in module di taudata ==> add if needed, misal 3D time series visualization.
#
# - Anomali dan outlier detection di data time series
#
# - Univariate forecasting: Exp Smoothing, (Auto) Arima,
#  * Struktur Data Time Series Darts
#  * Metrics evaluasi di Time Series: mse, R^2, Mape, Mase
#  * Trend
#  * Seasonal
#
# - Cross Validasi di Time Series: Backtest & metode lain, tapi utamakan yg ada modulenya.
#
# - Hyper parameter optimization in Time Series
#
# - Interpretasi Time Series Analysis:
#  * Kasih beberapa usecases
#  * Kasih Fallacies
#
# - Probabilistic forecasting
#
# - Dynamic Time Wrapping
#
# - Multivariate Forecasting R^N ==> R
#
# - Multivariate time series classification
#
# - Deep learning based forecasting.
#
# - Multivariate to multivariate forecasting (Sequence to Sequence model): R^N ==> R^N
#
# - Forecasting on New Dataset: Multi series forecasting
#
# - Transfer Learning
#
# - Buat Dashboard time series forecasting: Free Tableau/PowerBI
#
# - Buat forecasting app (realtime).
#
# Catatan:
# * Ada soal PreTest yang harus dilakukan ketika peserta sudah mendaftar.
# * Get additional (good) book/resources untuk pendahuluan:
#  - Introduction to Time Series Forecasting with Python How to Prepare Data and Develop Models to Predict the Future (Jason Brownlee) ==> Ada di folder Ref/ PostDoc
# * Mainly ikutin yg ada disini (customized):
#  - https://github.com/unit8co/darts/tree/master/examples
#  - https://unit8co.github.io/darts/userguide.html
# * Bagi jadi 2 series ... too much dalam satu seri
# * 3/4 materi, 1/4 akhir hanya latihan.
# * Yang mana masuk mana disesuaikan as time goes by
# * Utamakan semua topik adalah yg ada modulenya.

# %% [markdown]
# <center><h1><strong>taudata Analytics</strong></h1></center>
# <center><h2><strong><font color="blue">TSA-00: Pendahuluan Time-Series Forecasting</font></strong></h2></center>
# <img alt="" src="images/covers/taudata-cover.jpg"/>
#
# <b><center>(C) Taufik Sutanto</center>
# <center><h3><font color="blue">https://taudata.blogspot.com/2022/06/tsa-00.html</font></h3></center>
