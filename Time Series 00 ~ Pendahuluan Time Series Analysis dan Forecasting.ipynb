# %% [markdown]
# <center>
# <strong><b><font size="5">Time Series 00 ~ Pendahuluan Time Series Analysis & Forecasting</font></b></strong>
# <img alt="" src="images/covers/taudata-cover.jpg"/>
# </center>

# %% [markdown]
# # Pendahuluan
#
# Apa yang akan Anda lakukan jika Anda mengetahui seperti apa masa depan itu? Bagi sebagian orang, jawabannya mungkin "membeli bitcoin di tahun 2017." Bagi para pengecer, jawabannya mungkin "menimbun stok kertas toilet atau chip silikon di tahun 2019." Apa pun jawaban Anda, kita dapat sepakat bahwa memiliki informasi tentang masa depan akan sangat menguntungkan.
#
# Meskipun kita telah lama bertanya kepada peramal tentang apa yang akan terjadi di masa depan, memprediksi masa depan tetaplah sebuah tantangan. Bahkan dengan teknologi kita saat ini, prediksi cuaca satu jam ke depan bisa sangat keliru. Namun, untuk beberapa kasus, kita dapat memodelkan perilaku dari deret waktu dengan cukup baik sehingga memungkinkan untuk membuat prediksi masa depan yang cukup akurat.
#
# Analisis dan peramalan deret waktu adalah dua topik luas yang bisa terasa rumit. Oleh karena itu, artikel ini akan memperkenalkan konsep dasar dari kedua topik tersebut. Untuk menunjukkan beberapa konsep, kami akan menggunakan contoh kode dalam Python dan metode dari pustaka statsmodels [10]. Mari kita mulai!

# %% [markdown]
# # Definisi Peramalan Deret Waktu dan Analisis Deret Waktu
#
# Bagian ini akan mendefinisikan tiga istilah kunci: deret waktu, analisis deret waktu, dan peramalan deret waktu.
#
# ## Apa Itu Deret Waktu?
# Deret waktu adalah rangkaian titik data yang bergantung pada waktu. Artinya, setiap titik data memiliki cap waktu yang melekat padanya. Idealnya, titik-titik data ini diukur pada interval yang konstan (misalnya, setiap hari) dan dalam urutan kronologis (misalnya, Senin, Selasa, Rabu, dan seterusnya).
#
# <center><img alt="" src="images/timeseries/contoh-timeseries.png"/></center>

# %% [markdown]
# Deret waktu biasanya berupa nilai numerik, misalnya data penjualan, tetapi dapat juga berupa nilai kategorikal, seperti data kejadian. Data deret waktu biasanya disajikan dalam format tabular (misalnya, file CSV) dengan satu kolom untuk cap waktu dan setidaknya satu kolom untuk nilai deret waktu.
#
# <center><img alt="" src="images/timeseries/contoh-tabel-timeseries.png"/></center>

# %% [markdown]
# # Apa Itu Analisis Deret Waktu? (_Time Series Analysis_)
# Analisis deret waktu mirip dengan Analisis Data Eksploratif (EDA) dalam alur kerja Data Science karena menganalisis hubungan antar variabel dan nilai pencilan [3, 9]. Selain itu, analisis ini bertujuan menemukan tren jangka panjang atau pola berulang jangka pendek [3, 9].
#
# Seperti teknik EDA standar, pemetaan data dan perhitungan karakteristik statistik seperti rata-rata dan deviasi standar juga penting dalam analisis deret waktu [9]. Namun, diperlukan metode tambahan untuk mengeksplorasi dimensi waktu yang lebih kompleks (lihat Dasar-Dasar Analisis Deret Waktu).
#
# <center><img alt="" src="images/timeseries/apa-itu-tsa.png"/></center>
#
# Di satu sisi, analisis deret waktu dapat menjadi konsep yang berdiri sendiri. Di sisi lain, analisis ini dapat menjadi langkah EDA dalam alur kerja peramalan deret waktu karena wawasan yang diperoleh mengenai deret waktu dan polanya dapat membantu menentukan model yang akan digunakan [9].

# %% [markdown]
# # Apa Itu Peramalan Deret Waktu?  (_Time Series Forecasting_)
# Dalam peramalan deret waktu, kita berusaha memprediksi bagaimana kelanjutan dari serangkaian observasi di masa depan. Untuk tujuan ini, kita pertama-tama menganalisis data historis, mirip dengan analisis deret waktu. Kemudian, kita menerapkan model pada data historis tersebut untuk membuat prediksi.
#
# <center><img alt="" src="images/timeseries/apa-itu-tsf.png"/></center>
#
# Peramalan deret waktu memiliki berbagai macam pengaturan masalah. Perbedaan ini dapat dilihat dari aspek berikut:
# - jumlah deret waktu yang diamati untuk diprediksi (univariat vs. multivariat)
# - rentang waktu prediksi (jangka pendek vs. jangka panjang)

# %% [markdown]
# # **Kasus Penggunaan Analisis dan Peramalan Deret Waktu**
# Analisis dan peramalan deret waktu memiliki berbagai kasus penggunaan. Berikut beberapa contohnya:
#
# 1. **Keuangan**: Salah satu contoh paling populer dari peramalan deret waktu adalah prediksi harga saham. Meskipun banyak yang ingin mengetahui cara menghitung saham mana yang akan menjadi "Google" atau "Amazon" berikutnya, ini juga merupakan salah satu kasus penggunaan yang paling menantang dalam peramalan deret waktu.
#
# 2. **Cuaca**: Contoh umum lainnya dari peramalan deret waktu adalah prakiraan cuaca. Ini juga menjadi contoh yang baik untuk menunjukkan bahwa prakiraan dengan cakupan waktu prediksi yang lebih pendek (misalnya, cuaca esok hari) biasanya lebih dapat diandalkan dibandingkan dengan cakupan waktu prediksi yang lebih panjang (misalnya, cuaca seminggu dari sekarang).
#
# 3. **Permintaan**: Hampir semua yang berkaitan dengan permintaan adalah kasus penggunaan yang baik untuk analisis dan peramalan deret waktu. Contohnya meliputi pembangkitan listrik, inventaris toko, penjadwalan staf, jumlah penumpang di bus atau penerbangan, serta lalu lintas di jalan raya.
#
# Seperti yang dapat dilihat, beberapa jenis deret waktu lebih mudah untuk diprediksi dibandingkan yang lain. Hal ini bergantung pada faktor-faktor berikut [3]:
# - Seberapa baik kita memahami faktor-faktor yang memengaruhi?
# - Seberapa banyak data yang tersedia?
# - Seberapa mirip masa depan dengan masa lalu (lihat *Apa Itu Stasioneritas dan Mengapa Penting untuk Analisis Deret Waktu*?).

# %% [markdown]
# # **Dasar-Dasar Analisis Deret Waktu**
# Bagian ini akan memperkenalkan beberapa konsep penting dalam analisis deret waktu, yaitu komponen-komponen deret waktu dan stasioneritas.
#
# **Komponen-Komponen Deret Waktu**
# Ketika memilih metode peramalan, kita harus terlebih dahulu mengidentifikasi pola dalam data deret waktu dan kemudian memilih model yang dapat menangkap pola tersebut dengan tepat [3]. Sebuah deret waktu yang diamati dapat diuraikan menjadi lima komponen berikut:
# - **Level**: Nilai rata-rata.
# - **Tren**: Kecenderungan jangka panjang yang meningkat atau menurun.
# - **Musiman (Seasonality)**: Pola berulang jangka pendek pada periode tetap, misalnya mingguan, bulanan, atau tahunan.
# - **Siklus (Cycle)**: Pola berulang jangka pendek (tidak pada periode tetap).
# - **Noise**: Fluktuasi jangka pendek yang tidak teratur atau bahkan acak.
#
# Pola musiman dan siklikal sering sulit dibedakan dalam data deret waktu. Jika frekuensi pola berulang konstan terhadap kalender, maka pola tersebut dianggap musiman. Jika tidak, pola tersebut dianggap siklikal [3].
#
# Kita dapat menggunakan fungsi `seasonal_decompose()` dari pustaka *statsmodels* [10]. Ini adalah metode dekomposisi sederhana yang memisahkan deret waktu menjadi tiga komponen: tren, musiman, dan noise (residual) [10].

# %%
import warnings; warnings.simplefilter('ignore')

try:
    import google.colab
    IN_COLAB = True
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/Pedas-2024---Forecasting/master/data/international-airline-passengers.csv
    # !pip install statsmodels pmdarima darts nolds tsfresh --q
except:
    IN_COLAB = False
    print("Running the code locally, please make sure all the python module versions agree with colab environment and all data/assets downloaded")
# Out:
# Running the code locally, please make sure all the python module versions agree with colab environment and all data/assets downloaded

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')

import pandas as pd
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARMA, ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pmdarima as pm

from math import sqrt

import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'
import seaborn as sns

from random import random

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, mean_squared_log_error

"Done"
# Out:
# 'Done'

# %%
df = pd.read_csv('data/international-airline-passengers.csv')
df.head()
# Out:
#        year  passengers
# 0  1/1/1949         112
# 1  2/1/1949         118
# 2  3/1/1949         132
# 3  4/1/1949         129
# 4  5/1/1949         121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    object
#  1   passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df.describe(include='all')
# Out:
#             year  passengers
# count        144  144.000000
# unique       144         NaN
# top     1/1/1949         NaN
# freq           1         NaN
# mean         NaN  280.298611
# std          NaN  119.966317
# min          NaN  104.000000
# 25%          NaN  180.000000
# 50%          NaN  265.500000
# 75%          NaN  360.500000
# max          NaN  622.000000

# %%
df['year'] = pd.to_datetime(df['year'], format='%m/%d/%Y')
y = df.set_index('year')
y.plot(figsize=(15, 6))
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    datetime64[ns]
#  1   passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
fig, ax = plt.subplots(figsize=(15,6))
p = sns.boxplot(data=y, x=y.passengers.index.year, y= y.passengers, ax=ax)
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='multiplicative')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# # **Apa Itu Stasioneritas dan Mengapa Penting untuk Analisis Deret Waktu?**
# Stasioneritas menggambarkan konsep bahwa cara suatu deret waktu berubah akan tetap sama di masa depan [3]. Dalam istilah matematis, sebuah deret waktu dikatakan stasioner ketika sifat-sifat statistiknya (rata-rata, variansi, dan kovarians) tidak bergantung pada waktu [7].
#
# <center><img alt="" src="images/timeseries/stationarity.png"/></center>
#
# Ketika masa depan mirip dengan masa lalu, peramalan menjadi lebih mudah [3]. Oleh karena itu, deret waktu yang stasioner lebih mudah untuk dimodelkan dibandingkan dengan deret waktu yang tidak stasioner, karena sifat statistiknya akan tetap sama. Banyak model peramalan deret waktu yang mengasumsikan stasioneritas.
#
# Jika sebuah deret waktu tidak stasioner, Anda dapat mencoba membuatnya menjadi stasioner, misalnya dengan menggunakan metode *differencing*.

# %%
ts_log = np.log(y)
p = plt.plot(ts_log)
plt.show()

# %%
ts_log_diff = ts_log.passengers - ts_log.passengers.shift()
p = plt.plot(ts_log_diff)
plt.show()

# %% [markdown]
# # **Dasar-Dasar Peramalan Deret Waktu**
# Bagian ini akan membahas model-model peramalan deret waktu yang populer serta cara melatih dan memvalidasinya.
#
# ## **Model-Model Peramalan Deret Waktu yang Populer**
# Anda dapat mendekati peramalan deret waktu dengan berbagai model. Metode peramalan bervariasi mulai dari yang sederhana, seperti menggunakan observasi terakhir sebagai prediksi, hingga yang lebih kompleks menggunakan model pembelajaran mesin (ML) [3].
#
# <center><img alt="" src="images/timeseries/naive-forecast.png"/></center>
#
# 1. **Pendekatan Naif**: Dalam peramalan naif, nilai yang diprediksi hanya merupakan nilai dari observasi terbaru. Metode dasar ini sering digunakan sebagai tolok ukur untuk mengevaluasi kinerja model yang lebih canggih.
#
#    Oleh karena itu, sebagai langkah pertama saat Anda melacak eksperimen dengan Weights and Biases, disarankan untuk membuat baseline menggunakan pendekatan naif untuk menguji eksperimen Anda 💡.
#
# 2. **Peramalan Deret Waktu Berbasis Regresi**: Metode peramalan deret waktu berbasis regresi mengasumsikan bahwa deret waktu memiliki hubungan linier dengan deret waktu lainnya [3]. Asumsi tentang hubungan linier ini menghasilkan model untuk tren, tetapi bukan untuk musiman.
#
# 3. **Pelunakan Eksponensial (Exponential Smoothing)**: Pelunakan eksponensial diusulkan pada akhir 1950-an dan merupakan metode peramalan klasik [1, 2, 13]. Kepopulerannya berasal dari kenyataan bahwa metode ini menghasilkan peramalan yang dapat diandalkan (jangka pendek) dengan cepat, sementara memerlukan ruang memori yang relatif sedikit [3].
#
#    Metode peramalan ini menggunakan rata-rata berbobot dari observasi-observasi sebelumnya. Mengambil rata-rata dari semua observasi sebelumnya mengurangi noise dalam deret waktu (pelunakan), dan bobotnya berkurang secara eksponensial seiring bertambahnya usia observasi [3].

# %% [markdown]
# # **Autoregressive Integrated Moving Average (ARIMA)**:
#
# ARIMA adalah kelas metode peramalan yang memodelkan deret waktu berdasarkan autokorelasi-nya [3, 9]. Model ini merupakan kombinasi dari elemen-elemen berikut:
#
# 1. **Autoregressive (AR)**: Membuat prediksi berdasarkan kombinasi linier dari nilai-nilai masa lalunya.
# 2. **Moving Average (MA)**: Membuat prediksi berdasarkan kombinasi linier dari kesalahan peramalan masa lalu.
# 3. **Integrated (I)**: Membuat prediksi berdasarkan deret waktu yang telah dibedakan, yang berguna ketika deret waktu tidak stasioner (lihat *Apa Itu Stasioneritas dan Mengapa Penting untuk Analisis Deret Waktu?).
#
# <center><img alt="" src="images/timeseries/arima.png"/></center>
# <center><img alt="" src="images/timeseries/arima-vars.jpg"/></center>

# %%
import numpy as np
import pmdarima as pm
from pmdarima.datasets import load_wineind

# this is a dataset from R
wineind = load_wineind().astype(np.float64)

# fit stepwise auto-ARIMA
stepwise_fit = pm.auto_arima(wineind, start_p=1, start_q=1,
                             max_p=3, max_q=3, m=12,
                             start_P=0, seasonal=True,
                             d=1, D=1, trace=True,
                             error_action='ignore',  # don't want to know if an order does not work
                             suppress_warnings=True,  # don't want convergence warnings
                             stepwise=True)  # set to stepwise
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=3066.492, Time=0.53 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=3131.408, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=3097.884, Time=0.25 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=3066.329, Time=0.25 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=3089.456, Time=0.08 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=3067.457, Time=0.38 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=3067.481, Time=0.39 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=3071.631, Time=0.24 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=inf, Time=2.94 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=3117.921, Time=0.71 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=3065.533, Time=0.32 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=3087.883, Time=0.12 sec
#  ARIMA(0,1,2)(1,1,1)[12]             : AIC=3066.239, Time=0.47 sec
# ...

# %%
stepwise_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  176
# Model:               SARIMAX(2, 1, 1)   Log Likelihood               -1746.125
# Date:                Fri, 15 Nov 2024   AIC                           3500.251
# Time:                        17:45:00   BIC                           3512.910
# Sample:                             0   HQIC                          3505.386
#                                 - 176
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1420      0.109      1.307      0.191      -0.071       0.355
# ar.L2         -0.2572      0.125     -2.063      0.039      -0.502      -0.013
# ma.L1         -0.9074      0.052    -17.526      0.000      -1.009      -0.806
# ...

# %% [markdown]
# # Supervised Machine Learning sebagai Model Forecasting (univariate)
#
# <center><img alt="" src="images/timeseries/ml-forecasting-univariate.png"/></center>

# %% [markdown]
# # Supervised Machine Learning sebagai Model Forecasting (multivariate)
#
# <center><img alt="" src="images/timeseries/ml-forecasting-multivariate.png"/></center>

# %% [markdown]
# # Pengalaman Pribadi
#
# <center><img alt="" src="images/timeseries/model-comparisons.png"/></center>

# %% [markdown]
# # Peta Time Series Analysis dan Forecasting
#
# <center><img alt="" src="images/timeseries/ts-map.jpg"/></center>

# %% [markdown]
# # References
#
# 1.  R. G. Brown (1959). Statistical forecasting for inventory control. McGraw/Hill.
# 2.  C. C. Holt (1957). Forecasting seasonals and trends by exponentially weighted averages (ONR Memorandum No 52). Carnegie Institute of Technology, Pittsburgh USA. Reprinted in the International Journal of Forecasting, 2004. https://www.sciencedirect.com/science/article/abs/pii/S0169207003001134?via%3Dihub
# 3.  R. J. Hyndman, & G. Athanasopoulos (2021) Forecasting: principles and practice, 3rd edition, OTexts: Melbourne, Australia. OTexts.com/fpp3 . (Accessed on September 26, 2022).
# 4.  Y. In(2019) 1st place solution. https://www.kaggle.com/competitions/m5-forecasting-accuracy/discussion/163684 (accessed October 1st, 2022)
# 5.  “Jeon” (2019). 3rd place solution - NN approach. https://www.kaggle.com/competitions/m5-forecasting-accuracy/discussion/164374 (accessed October 1st, 2022)
# 6.  “Matthias” (2019). 2nd place solution. https://www.kaggle.com/competitions/m5-forecasting-accuracy/discussion/164599 (accessed October 1st, 2022)
# 7.  A. Mikusheva (2009) “Stationarity, Lag Operator, ARMA, and Covariance Structure” Lecture notes of 14.384 Time Series Analysis
# 8.  MOFC (2017). The M5 Competition. https://mofc.unic.ac.cy/m5-competition/ (accessed October 1st, 2022)
# 9. D. C. Montgomery, C. L. Jennings, Murat Kulahci (2015) Introduction to Time Series Analysis and Forecasting, 2nd edition, John Wiley & Sons.
# 10.  J. Perktold, S. Seabold, J. Taylor (2009). statsmodels. https://www.statsmodels.org/stable/index.html (accessed October 1st, 2022)
# 11. “scikit-learn developers” (2007) sklearn.model_selection.TimeSeriesSplit. https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html#sklearn.model_selection.TimeSeriesSplit (accessed October 1st, 2022)
# 12. S. J. Taylor and B. Letham (2017). Forecasting at scale. PeerJ Preprints 5:e3190v2 https://doi.org/10.7287/peerj.preprints.3190v2
# 13. P. R. Winters (1960). Forecasting sales by exponentially weighted moving averages. Management Science, 6(3), 324–342. https://pubsonline.informs.org/doi/10.1287/mnsc.6.3.324

# %% [markdown]
# # End of Module
# <hr>
